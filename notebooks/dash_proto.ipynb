# %% [markdown]
# # Dashboard prototype charts
#
# This notebook is to get some insights about _Anime_ dataset scrapped from internet, and identify the most relevant information to display it in a future dashboard.
#
# First of all, we import required libraries.

# %%
import os
import re
import pandas as pd
import matplotlib.pyplot as plt

from ast import literal_eval

# Relative paths
__file__ = 'dash_proto.ipynb'
CURRENT = os.path.dirname(os.path.abspath(__file__))
ROOT = os.path.dirname(CURRENT)

# %% [markdown]
# An initial inspection of the dataset

# %%
DATA_PATH = os.path.join(ROOT, 'data/clean/anime_data_clean.csv')

anime = pd.read_csv(DATA_PATH)
anime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 65 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ranking           100 non-null    int64
#  1   score             100 non-null    float64
#  2   title             100 non-null    object
#  3   emission_date     100 non-null    object
#  4   url               100 non-null    object
#  5   studio            100 non-null    object
#  6   themes            100 non-null    object
#  7   genres            100 non-null    object
#  8   demographics      60 non-null     object
#  9   emission_type     100 non-null    object
#  10  number_episode    99 non-null     float64
#  11  members           100 non-null    int64
#  12  first_emission    98 non-null     object
#  13  last_emission     97 non-null     object
#  14  Adult Cast        100 non-null    int64
#  15  Anthropomorphic   100 non-null    int64
#  16  CGDCT             100 non-null    int64
#  17  Childcare         100 non-null    int64
#  18  Combat Sports     100 non-null    int64
#  19  Delinquents       100 non-null    int64
#  20  Detective         100 non-null    int64
#  21  Gag Humor         100 non-null    int64
#  22  Gore              100 non-null    int64
#  23  Historical        100 non-null    int64
#  24  Isekai            100 non-null    int64
#  25  Iyashikei         100 non-null    int64
#  26  Love Polygon      100 non-null    int64
#  27  Martial Arts      100 non-null    int64
#  28  Mecha             100 non-null    int64
#  29  Military          100 non-null    int64
#  30  Music             100 non-null    int64
#  31  Mythology         100 non-null    int64
#  32  Not_available     100 non-null    int64
#  33  Organized Crime   100 non-null    int64
#  34  Parody            100 non-null    int64
#  35  Performing Arts   100 non-null    int64
#  36  Psychological     100 non-null    int64
#  37  Reincarnation     100 non-null    int64
#  38  Romantic Subtext  100 non-null    int64
#  39  Samurai           100 non-null    int64
#  40  School            100 non-null    int64
#  41  Space             100 non-null    int64
#  42  Strategy Game     100 non-null    int64
#  43  Super Power       100 non-null    int64
#  44  Survival          100 non-null    int64
#  45  Team Sports       100 non-null    int64
#  46  Time Travel       100 non-null    int64
#  47  Vampire           100 non-null    int64
#  48  Workplace         100 non-null    int64
#  49  Action            100 non-null    int64
#  50  Adventure         100 non-null    int64
#  51  Award Winning     100 non-null    int64
#  52  Comedy            100 non-null    int64
#  53  Drama             100 non-null    int64
#  54  Ecchi             100 non-null    int64
#  55  Fantasy           100 non-null    int64
#  56  Horror            100 non-null    int64
#  57  Mystery           100 non-null    int64
#  58  Not_available.1   100 non-null    int64
#  59  Romance           100 non-null    int64
#  60  Sci-Fi            100 non-null    int64
#  61  Slice of Life     100 non-null    int64
#  62  Sports            100 non-null    int64
#  63  Supernatural      100 non-null    int64
#  64  Suspense          100 non-null    int64
# dtypes: float64(2), int64(53), object(10)
# memory usage: 50.9+ KB

# %% [markdown]
# Global string formating functions

# %%
def global_format(x):
    x = re.sub(pattern=r"[°.-]+", repl='_', string=x)
    x = re.sub(pattern="'s", repl='', string=x)
    return x

# %% [markdown]
# Encoded genres start after column 13. We can filter previous columns and apply some convenient transformations for catalog building and further analysis.

# %%
# Dataset column names format
anime.columns = ['_'.join(col_.split(sep=' ')).lower() for col_ in anime.columns]

# Convenient dataset content tranformations
test = (
    anime
    # Ignore encoded columns
    .filter(items=anime.columns[0:13])
    # Transformations in existing columns
    .assign(
        # studio column in snake case
        studio = lambda df_: (
            df_
            .studio
            # Replace whitespace with '_' in column
            .apply( lambda val_: '_'.join(val_.split(sep=' ')).lower() )
            # Remove abnormal characters in column
            .apply(global_format)
        )
        # themes column in snake case
        ,themes = lambda df_: (
            df_.
            themes
            .apply(
                # Additional lambda required to handle list like data in cell
                lambda val_: [
                    # Remove abnormal characters in column
                    global_format(
                        # Replace whitespace with '_' in element
                        '_'.join(k.split(' ')).lower()
                    ) for k in literal_eval(val_) ]
            )
        )
        # genres column in snake case
        ,genres = lambda df_: (
            df_.genres.apply(
                # Additional lambda required to handle list like data in cell
                lambda val_: [
                    # Remove abnormal characters in column
                    global_format(
                        # Replace whitespace with '_' in element
                        '_'.join(k.split(' ')).lower()
                    ) for k in literal_eval(val_) ]
            )
        )
    )
)

test.head()
# Out:
#    ranking  score                                              title  \
# 0        1   9.13  Shingeki no Kyojin: The Final Season - Kankets...
# 1        2   9.11                   Fullmetal Alchemist: Brotherhood
# 2        3   9.08                          Bleach: Sennen Kessen-hen
# 3        4   9.08                                        Steins;Gate
# 4        5   9.07                                           Gintama°
#
#          emission_date                                                url  \
# 0      Mar 2023 - 2023  https://myanimelist.net/anime/51535/Shingeki_n...
# 1  Apr 2009 - Jul 2010  https://myanimelist.net/anime/5114/Fullmetal_A...
# 2  Oct 2022 - Dec 2022  https://myanimelist.net/anime/41467/Bleach__Se...
# 3  Apr 2011 - Sep 2011     https://myanimelist.net/anime/9253/Steins_Gate
# 4  Apr 2015 - Mar 2016       https://myanimelist.net/anime/28977/Gintama°
#
#                   studio                                    themes  \
# 0                  mappa                [gore, military, survival]
# 1                  bones                                [military]
# 2                pierrot                           [not_available]
# 3              white_fox              [psychological, time_travel]
# 4  bandai_namco_pictures  [gag_humor, historical, parody, samurai]
#
#                                 genres demographics emission_type  \
# 0            [action, drama, suspense]      Shounen      Special
# 1  [action, adventure, drama, fantasy]      Shounen           TV
# 2         [action, adventure, fantasy]      Shounen           TV
# 3            [drama, sci_fi, suspense]          NaN           TV
# 4             [action, comedy, sci_fi]      Shounen           TV
#
#    number_episode  members first_emission
# 0             2.0   372149     2023-03-01
# 1            64.0  3120633     2009-04-01
# 2            13.0   411507     2022-10-01
# 3            24.0  2401772     2011-04-01
# 4            51.0   584278     2015-04-01
